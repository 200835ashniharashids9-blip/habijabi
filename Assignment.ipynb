# %% [markdown]
# <a href="https://colab.research.google.com/github/200835ashniharashids9-blip/habijabi/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment-**1**

# %%
#Q-1
name='Ashniha Rashid'
age=22
favourite_color="Black"
print("Name:",name)
print("Age:",age)
print("Favourite color:",favourite_color)
# Out:
# Name: Ashniha Rashid
# Age: 22
# Favourite color: Black

# %%
#Q-2

name="Ashniha"
address="Dhaka"
age=22
price=99.99
is_valid=True
has_paid=False
result="none"
print(type(name))
print(type(address))
print(type(age))
print(type(price))
print(type(is_valid))
print(type(has_paid))
print(type(result))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>

# %%
#Q-3
length=7
width=5
area=length*width
print('Area:',area)
perimeter=2*(length+width)
print("Perimeter:",perimeter)
# Out:
# Area: 35
# Perimeter: 24

# %%
#Q-4
foods=["kacchi","pizza","pasta","noodles","roast"]
print(foods[0])
print(foods[4])
print(foods[-2])
print(foods[1:3]) #1,2 dekhabe ,3 dekhabe na,3 dekhte caile 1: 4dibo
foods[1]="meatbox"
print(foods)
foods.sort()
print(foods)
# Out:
# kacchi
# roast
# noodles
# ['pizza', 'pasta']
# ['kacchi', 'meatbox', 'pasta', 'noodles', 'roast']
# ['kacchi', 'meatbox', 'noodles', 'pasta', 'roast']

# %%
#Q-5
numbers=["999","888","7777","66","33333"]
numbers.append("0000000")
print(numbers)
numbers.sort()
numbers.remove("66")
print(numbers)
# Out:
# ['999', '888', '7777', '66', '33333', '0000000']
# ['0000000', '33333', '7777', '888', '999']

# %%
#Q-6
student={"name":"Ashniha","age":21,"University":"DU","courses":["ODE 2","Mathematical Methods","MATLAB","Mathematica","Fortran"]}
print(student)
print(student["name"])
print(student["courses"])
#if "email" in student: print("Email found") else: print("No email found")
  student["phone"]="01767765370"
  print(student)
# Out:
#   File "/tmp/ipython-input-1398162436.py", line 7
#     student["phone"]="01767765370"
#     ^
# IndentationError: unexpected indent

# %%
#Q-7
#Latitude_and_longitude_of-coxs_bazar
coordinates=(21.4397,92.0096)
print(coordinates)
# Out:
# (21.4397, 92.0096)

# %%
#Q-8
colors={"red","green","blue","black","pink","blue"}
print(colors)
rgb_color={"red","green","blue"}
other_colors={"pink","black","red"}
all_colors=rgb_color|other_colors
common_color=rgb_color & other_colors
print(all_colors)
print(common_color)
# Out:
# {'green', 'black', 'pink', 'blue', 'red'}
# {'green', 'black', 'pink', 'blue', 'red'}
# {'red'}

# %%
#Q-9
text="Mathematics"
print(text[0])
print(text[10])
# Out:
# M
# s

# %%
#Q-10
"mathematics".upper()
# Out:
# 'MATHEMATICS'
